# %%
import pandas as pd

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data.sort_values("Ja in Prozent")
# Out:
#       Kantons-Nummer                            Kanton  Gemeinde-Nummer  \
# 1959              23                   Valais / Wallis             6172
# 364                2                      Bern / Berne              715
# 1404              19                            Aargau             4314
# 361                2                      Bern / Berne              709
# 352                2                      Bern / Berne              694
# ...              ...                               ...              ...
# 2087              25                            Genève             6642
# 748               10               Fribourg / Freiburg             2261
# 2062              25                            Genève             6617
# 1499              21                            Ticino             5063
# 1166              18  Graubünden / Grigioni / Grischun             3804
#
#          Gemeinde Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# ...

# %%
data.sort_values("Ja in Prozent", ascending=False)
# Out:
#       Kantons-Nummer                            Kanton  Gemeinde-Nummer  \
# 1166              18  Graubünden / Grigioni / Grischun             3804
# 1499              21                            Ticino             5063
# 2062              25                            Genève             6617
# 748               10               Fribourg / Freiburg             2261
# 2087              25                            Genève             6642
# ...              ...                               ...              ...
# 352                2                      Bern / Berne              694
# 361                2                      Bern / Berne              709
# 1404              19                            Aargau             4314
# 364                2                      Bern / Berne              715
# 1959              23                   Valais / Wallis             6172
#
#          Gemeinde Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# ...

# %%
data.sort_values(["Ja in Prozent", "Ja-Stimmen"], ascending=[False, False])
# Out:
#       Kantons-Nummer                            Kanton  Gemeinde-Nummer  \
# 1166              18  Graubünden / Grigioni / Grischun             3804
# 1499              21                            Ticino             5063
# 2062              25                            Genève             6617
# 748               10               Fribourg / Freiburg             2261
# 2087              25                            Genève             6642
# ...              ...                               ...              ...
# 352                2                      Bern / Berne              694
# 361                2                      Bern / Berne              709
# 1404              19                            Aargau             4314
# 364                2                      Bern / Berne              715
# 1959              23                   Valais / Wallis             6172
#
#          Gemeinde Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# ...

# %%
data["Gemeinde"]
# Out:
# 0           Aeugst am Albis
# 1        Affoltern am Albis
# 2                Bonstetten
# 3           Hausen am Albis
# 4                  Hedingen
#                ...
# 2151          AG-Ausland-CH
# 2152          TG-Ausland-CH
# 2153    VD-CH de l'étranger
# 2154    VS-CH de l'étranger
# 2155    GE-CH de l'étranger
# Name: Gemeinde, Length: 2156, dtype: object

# %%
data[["Gemeinde", "Kanton"]]
# Out:
#                  Gemeinde           Kanton
# 0         Aeugst am Albis           Zürich
# 1      Affoltern am Albis           Zürich
# 2              Bonstetten           Zürich
# 3         Hausen am Albis           Zürich
# 4                Hedingen           Zürich
# ...                   ...              ...
# 2151        AG-Ausland-CH           Aargau
# 2152        TG-Ausland-CH          Thurgau
# 2153  VD-CH de l'étranger             Vaud
# 2154  VS-CH de l'étranger  Valais / Wallis
# 2155  GE-CH de l'étranger           Genève
#
# [2156 rows x 2 columns]

# %%
data["Ja in Prozent"] >= 50
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2151    False
# 2152    False
# 2153    False
# 2154    False
# 2155    False
# Name: Ja in Prozent, Length: 2156, dtype: bool

# %%
data[data["Ja in Prozent"] >= 50]
# Out:
#       Kantons-Nummer  Kanton  Gemeinde-Nummer         Gemeinde  \
# 25                 1  Zürich               32         Humlikon
# 64                 1  Zürich               88          Neerach
# 91                 1  Zürich              135   Kilchberg (ZH)
# 95                 1  Zürich              139       Rüschlikon
# 97                 1  Zürich              151   Erlenbach (ZH)
# ...              ...     ...              ...              ...
# 2070              25  Genève             6625         Hermance
# 2071              25  Genève             6626            Jussy
# 2079              25  Genève             6634  Pregny-Chambésy
# 2087              25  Genève             6642      Vandoeuvres
# 2090              25  Genève             6645          Veyrier
#
#      Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# 25                347                    173              49.9
# 64              2'395                  1'294              54.0
# ...

# %%
data[data["Kanton"] == "Zürich"]
# Out:
#       Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0                  1  Zürich                1     Aeugst am Albis
# 1                  1  Zürich                2  Affoltern am Albis
# 2                  1  Zürich                3          Bonstetten
# 3                  1  Zürich                4     Hausen am Albis
# 4                  1  Zürich                5            Hedingen
# ...              ...     ...              ...                 ...
# 158                1  Zürich              295              Horgen
# 159                1  Zürich              296   Illnau-Effretikon
# 160                1  Zürich              297               Bauma
# 161                1  Zürich              298        Wiesendangen
# 2144               1  Zürich             9010       ZH-Ausland-CH
#
#      Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# 0               1'415                    771              54.5
# ...

# %%
# For dates:
# data[data["date"] > "2022-12-31"]

# %%
in_zürich = data["Kanton"] == "Zürich"
voted_yes = data["Ja in Prozent"] > 50
data[in_zürich & voted_yes]
# Out:
#      Kantons-Nummer  Kanton  Gemeinde-Nummer        Gemeinde Stimmberechtigte  \
# 25                1  Zürich               32        Humlikon              347
# 64                1  Zürich               88         Neerach            2'395
# 91                1  Zürich              135  Kilchberg (ZH)            5'004
# 95                1  Zürich              139      Rüschlikon            3'357
# 97                1  Zürich              151  Erlenbach (ZH)            3'482
# 98                1  Zürich              152      Herrliberg            4'273
# 100               1  Zürich              154   Küsnacht (ZH)            8'788
# 102               1  Zürich              156          Meilen            9'075
# 106               1  Zürich              160         Zumikon            3'410
# 107               1  Zürich              161        Zollikon            7'977
# 127               1  Zürich              213         Brütten            1'593
# ...

# %%
data[(data["Kanton"] == "Zürich") & (data["Ja in Prozent"] > 50)]
# Out:
#      Kantons-Nummer  Kanton  Gemeinde-Nummer        Gemeinde Stimmberechtigte  \
# 25                1  Zürich               32        Humlikon              347
# 64                1  Zürich               88         Neerach            2'395
# 91                1  Zürich              135  Kilchberg (ZH)            5'004
# 95                1  Zürich              139      Rüschlikon            3'357
# 97                1  Zürich              151  Erlenbach (ZH)            3'482
# 98                1  Zürich              152      Herrliberg            4'273
# 100               1  Zürich              154   Küsnacht (ZH)            8'788
# 102               1  Zürich              156          Meilen            9'075
# 106               1  Zürich              160         Zumikon            3'410
# 107               1  Zürich              161        Zollikon            7'977
# 127               1  Zürich              213         Brütten            1'593
# ...

# %%
is_near_zürich_nord = data["Gemeinde"].isin(["Opfikon", "Kloten", "Rümlang"])
data[is_near_zürich_nord]
# Out:
#     Kantons-Nummer  Kanton  Gemeinde-Nummer Gemeinde Stimmberechtigte  \
# 46               1  Zürich               62   Kloten           11'216
# 50               1  Zürich               66  Opfikon            9'275
# 73               1  Zürich               97  Rümlang            4'551
#
#    eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 46                  3'991              35.6                81
# 50                  3'239              34.9                65
# 73                  1'690              37.1                31
#
#     ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# 46                      0           3'910      1'444        2'466
# 50                      0           3'174      1'288        1'886
# 73                      0           1'659        553        1'106
#
#     Ja in Prozent
# 46           36.9
# 50           40.6
# 73           33.3
