# %%
import pandas as pd

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data = data.drop_duplicates(subset="Gemeinde")
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data = data.drop_duplicates(subset=["Kanton", "Gemeinde"])
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data["Kanton"].value_counts()
# Out:
# Bern / Berne                        334
# Vaud                                301
# Aargau                              201
# Zürich                              163
# Fribourg / Freiburg                 127
# Valais / Wallis                     123
# Ticino                              108
# Solothurn                           107
# Graubünden / Grigioni / Grischun    101
# Basel-Landschaft                     86
# Luzern                               81
# Thurgau                              81
# St. Gallen                           78
# Jura                                 53
# Genève                               46
# Schwyz                               30
# Neuchâtel                            27
# Schaffhausen                         26
# Appenzell Ausserrhoden               20
# Uri                                  20
# Zug                                  11
# Nidwalden                            11
# Appenzell Innerrhoden                 7
# ...

# %%
data["Kanton"].value_counts(sort=False)
# Out:
# Zürich                              163
# Bern / Berne                        334
# Luzern                               81
# Uri                                  20
# Schwyz                               30
# Obwalden                              7
# Nidwalden                            11
# Glarus                                3
# Zug                                  11
# Fribourg / Freiburg                 127
# Solothurn                           107
# Basel-Stadt                           4
# Basel-Landschaft                     86
# Schaffhausen                         26
# Appenzell Ausserrhoden               20
# Appenzell Innerrhoden                 7
# St. Gallen                           78
# Graubünden / Grigioni / Grischun    101
# Aargau                              201
# Thurgau                              81
# Ticino                              108
# Vaud                                301
# Valais / Wallis                     123
# ...

# %%
data["Kanton"].value_counts(normalize=True, sort=True)
# Out:
# Bern / Berne                        0.154917
# Vaud                                0.139610
# Aargau                              0.093228
# Zürich                              0.075603
# Fribourg / Freiburg                 0.058905
# Valais / Wallis                     0.057050
# Ticino                              0.050093
# Solothurn                           0.049629
# Graubünden / Grigioni / Grischun    0.046846
# Basel-Landschaft                    0.039889
# Luzern                              0.037570
# Thurgau                             0.037570
# St. Gallen                          0.036178
# Jura                                0.024583
# Genève                              0.021336
# Schwyz                              0.013915
# Neuchâtel                           0.012523
# Schaffhausen                        0.012059
# Appenzell Ausserrhoden              0.009276
# Uri                                 0.009276
# Zug                                 0.005102
# ...
