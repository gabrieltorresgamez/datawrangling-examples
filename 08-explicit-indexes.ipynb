# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data = data.set_index("Gemeinde-Nummer")
data.head()
# Out:
#                  Kantons-Nummer  Kanton            Gemeinde Stimmberechtigte  \
# Gemeinde-Nummer
# 1                             1  Zürich     Aeugst am Albis            1'415
# 2                             1  Zürich  Affoltern am Albis            7'248
# 3                             1  Zürich          Bonstetten            3'665
# 4                             1  Zürich     Hausen am Albis            2'603
# 5                             1  Zürich            Hedingen            2'504
#
#                 eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# Gemeinde-Nummer
# 1                                  771              54.5                10
# 2                                3'284              45.3                59
# 3                                1'952              53.3                24
# 4                                1'378              52.9                33
# 5                                1'396              55.8                24
#
# ...

# %%
data = data.reset_index(drop = True)
data = data.drop("Kantons-Nummer", axis = 1)
data.head()
# Out:
#    Kanton            Gemeinde Stimmberechtigte eingelegte Stimmzettel  \
# 0  Zürich     Aeugst am Albis            1'415                    771
# 1  Zürich  Affoltern am Albis            7'248                  3'284
# 2  Zürich          Bonstetten            3'665                  1'952
# 3  Zürich     Hausen am Albis            2'603                  1'378
# 4  Zürich            Hedingen            2'504                  1'396
#
#    Stimmbeteiligung leere Stimmzettel  ungültige Stimmzettel gültige Stimmen  \
# 0              54.5                10                      0             761
# 1              45.3                59                      0           3'225
# 2              53.3                24                      0           1'928
# 3              52.9                33                      0           1'345
# 4              55.8                24                      0           1'372
#
#   Ja-Stimmen Nein-Stimmen  Ja in Prozent
# ...

# %%
data = data.set_index("Gemeinde")
data.loc[["Kloten", "Opfikon"]]
# Out:
#           Kanton Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# Gemeinde
# Kloten    Zürich           11'216                  3'991              35.6
# Opfikon   Zürich            9'275                  3'239              34.9
#
#          leere Stimmzettel  ungültige Stimmzettel gültige Stimmen Ja-Stimmen  \
# Gemeinde
# Kloten                  81                      0           3'910      1'444
# Opfikon                 65                      0           3'174      1'288
#
#          Nein-Stimmen  Ja in Prozent
# Gemeinde
# Kloten          2'466           36.9
# Opfikon         1'886           40.6

# %%
data = data.reset_index()
data = data.set_index(["Kanton", "Gemeinde"])
data.loc["Zürich"].head()
# Out:
#                    Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# Gemeinde
# Aeugst am Albis               1'415                    771              54.5
# Affoltern am Albis            7'248                  3'284              45.3
# Bonstetten                    3'665                  1'952              53.3
# Hausen am Albis               2'603                  1'378              52.9
# Hedingen                      2'504                  1'396              55.8
#
#                    leere Stimmzettel  ungültige Stimmzettel gültige Stimmen  \
# Gemeinde
# Aeugst am Albis                   10                      0             761
# Affoltern am Albis                59                      0           3'225
# Bonstetten                        24                      0           1'928
# Hausen am Albis                   33                      0           1'345
# Hedingen                          24                      0           1'372
#
# ...

# %%
data.loc[[("Zürich", "Kloten"), ("Aargau", "Brugg")]].head()
# Out:
#                 Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung  \
# Kanton Gemeinde
# Zürich Kloten             11'216                  3'991              35.6
# Aargau Brugg               7'691                  3'549              46.1
#
#                 leere Stimmzettel  ungültige Stimmzettel gültige Stimmen  \
# Kanton Gemeinde
# Zürich Kloten                  81                      0           3'910
# Aargau Brugg                   68                      0           3'481
#
#                 Ja-Stimmen Nein-Stimmen  Ja in Prozent
# Kanton Gemeinde
# Zürich Kloten        1'444        2'466           36.9
# Aargau Brugg         1'281        2'200           36.8

# %%
data = data.sort_index()
data.head()
# Out:
#                      Stimmberechtigte eingelegte Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH           11'559                  2'442
#        Aarau                   14'325                  7'135
#        Aarburg                  4'002                  1'379
#        Abtwil                     686                    290
#        Ammerswil                  497                    227
#
#                       Stimmbeteiligung leere Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH              21.1                46
#        Aarau                      49.8               150
#        Aarburg                    34.5                33
#        Abtwil                     42.3                 5
#        Ammerswil                  45.7                 4
#
#                       ungültige Stimmzettel gültige Stimmen Ja-Stimmen  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH                      0           2'396      1'055
# ...

# %%
data = data.sort_index(level = ["Gemeinde", "Kanton"], ascending = [True, False])
data.head()
# Out:
#                                     Stimmberechtigte eingelegte Stimmzettel  \
# Kanton                Gemeinde
# Aargau                AG-Ausland-CH           11'559                  2'442
# Appenzell Innerrhoden AI-Ausland-CH              523                    117
# Thurgau               Aadorf                   6'313                  2'590
# Aargau                Aarau                   14'325                  7'135
# Bern / Berne          Aarberg                  3'324                  1'511
#
#                                      Stimmbeteiligung leere Stimmzettel  \
# Kanton                Gemeinde
# Aargau                AG-Ausland-CH              21.1                46
# Appenzell Innerrhoden AI-Ausland-CH              22.4                 0
# Thurgau               Aadorf                     41.0                54
# Aargau                Aarau                      49.8               150
# Bern / Berne          Aarberg                    45.5                36
#
# ...
