# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data = data.drop(["Kantons-Nummer", "Gemeinde-Nummer"], axis = 1)
data.head()
# Out:
#    Kanton            Gemeinde Stimmberechtigte eingelegte Stimmzettel  \
# 0  Zürich     Aeugst am Albis            1'415                    771
# 1  Zürich  Affoltern am Albis            7'248                  3'284
# 2  Zürich          Bonstetten            3'665                  1'952
# 3  Zürich     Hausen am Albis            2'603                  1'378
# 4  Zürich            Hedingen            2'504                  1'396
#
#    Stimmbeteiligung leere Stimmzettel  ungültige Stimmzettel gültige Stimmen  \
# 0              54.5                10                      0             761
# 1              45.3                59                      0           3'225
# 2              53.3                24                      0           1'928
# 3              52.9                33                      0           1'345
# 4              55.8                24                      0           1'372
#
#   Ja-Stimmen Nein-Stimmen  Ja in Prozent
# ...

# %%
data["Gemeinde"].values[2:5]
# Out:
# array(['Bonstetten', 'Hausen am Albis', 'Hedingen'], dtype=object)

# %%
data = data.set_index(["Kanton", "Gemeinde"]).sort_index()
data.head()
# Out:
#                      Stimmberechtigte eingelegte Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH           11'559                  2'442
#        Aarau                   14'325                  7'135
#        Aarburg                  4'002                  1'379
#        Abtwil                     686                    290
#        Ammerswil                  497                    227
#
#                       Stimmbeteiligung leere Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH              21.1                46
#        Aarau                      49.8               150
#        Aarburg                    34.5                33
#        Abtwil                     42.3                 5
#        Ammerswil                  45.7                 4
#
#                       ungültige Stimmzettel gültige Stimmen Ja-Stimmen  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH                      0           2'396      1'055
# ...

# %%
data.loc["Aargau":"Basel-Stadt"]
# Out:
#                                Stimmberechtigte eingelegte Stimmzettel  \
# Kanton           Gemeinde
# Aargau           AG-Ausland-CH           11'559                  2'442
#                  Aarau                   14'325                  7'135
#                  Aarburg                  4'002                  1'379
#                  Abtwil                     686                    290
#                  Ammerswil                  497                    227
# ...                                         ...                    ...
# Basel-Landschaft Zwingen                  1'609                    547
# Basel-Stadt      BS-Ausland-CH            9'480                  2'138
#                  Basel                   90'987                 45'418
#                  Bettingen                  724                    443
#                  Riehen                  13'009                  7'520
#
#                                 Stimmbeteiligung leere Stimmzettel  \
# ...

# %%
data.loc[("Aargau", "Aarau"):("Basel-Stadt", "Basel")]
# Out:
#                                Stimmberechtigte eingelegte Stimmzettel  \
# Kanton           Gemeinde
# Aargau           Aarau                   14'325                  7'135
#                  Aarburg                  4'002                  1'379
#                  Abtwil                     686                    290
#                  Ammerswil                  497                    227
#                  Aristau                  1'017                    445
# ...                                         ...                    ...
# Basel-Landschaft Ziefen                   1'178                    576
#                  Zunzgen                  1'830                    775
#                  Zwingen                  1'609                    547
# Basel-Stadt      BS-Ausland-CH            9'480                  2'138
#                  Basel                   90'987                 45'418
#
#                                 Stimmbeteiligung leere Stimmzettel  \
# ...

# %%
data.loc[:, "Stimmberechtigte":"gültige Stimmen"]
# Out:
#                      Stimmberechtigte eingelegte Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH           11'559                  2'442
#        Aarau                   14'325                  7'135
#        Aarburg                  4'002                  1'379
#        Abtwil                     686                    290
#        Ammerswil                  497                    227
# ...                               ...                    ...
# Zürich ZH-Ausland-CH           32'816                  7'005
#        Zell (ZH)                4'059                  1'692
#        Zollikon                 7'977                  4'597
#        Zumikon                  3'410                  2'003
#        Zürich                 233'859                119'381
#
#                       Stimmbeteiligung leere Stimmzettel  \
# Kanton Gemeinde
# Aargau AG-Ausland-CH              21.1                46
#        Aarau                      49.8               150
# ...

# %%
data.loc[("Aargau", "Aarau"):("Basel-Stadt", "Basel"), "Stimmberechtigte":"gültige Stimmen"]
# Out:
#                                Stimmberechtigte eingelegte Stimmzettel  \
# Kanton           Gemeinde
# Aargau           Aarau                   14'325                  7'135
#                  Aarburg                  4'002                  1'379
#                  Abtwil                     686                    290
#                  Ammerswil                  497                    227
#                  Aristau                  1'017                    445
# ...                                         ...                    ...
# Basel-Landschaft Ziefen                   1'178                    576
#                  Zunzgen                  1'830                    775
#                  Zwingen                  1'609                    547
# Basel-Stadt      BS-Ausland-CH            9'480                  2'138
#                  Basel                   90'987                 45'418
#
#                                 Stimmbeteiligung leere Stimmzettel  \
# ...

# %%
data = data.reset_index()
data = data.set_index("Ja in Prozent").sort_index(ascending = False)
data[75:65] # works with dates (year, year-month, year-month-day) too
# Out:
#                                          Kanton     Gemeinde Stimmberechtigte  \
# Ja in Prozent
# 75.0           Graubünden / Grigioni / Grischun       Buseno               77
# 67.6                                     Ticino     Bedretto              104
# 66.4                                     Genève      Cologny            3'013
# 65.6                        Fribourg / Freiburg        Greng              126
# 65.2                                     Genève  Vandoeuvres            1'547
#
#               eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# Ja in Prozent
# 75.0                              30              39.0                 2
# 67.6                              35              33.7                 1
# 66.4                           1'448              48.1                51
# 65.6                              66              52.4                 2
# 65.2                             816              52.7                21
#
# ...

# %%
data.iloc[:5, :4]
# Out:
#                                          Kanton     Gemeinde Stimmberechtigte  \
# Ja in Prozent
# 75.0           Graubünden / Grigioni / Grischun       Buseno               77
# 67.6                                     Ticino     Bedretto              104
# 66.4                                     Genève      Cologny            3'013
# 65.6                        Fribourg / Freiburg        Greng              126
# 65.2                                     Genève  Vandoeuvres            1'547
#
#               eingelegte Stimmzettel
# Ja in Prozent
# 75.0                              30
# 67.6                              35
# 66.4                           1'448
# 65.6                              66
# 65.2                             816
