# %%
import pandas as pd

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data.groupby("Kanton")["Ja in Prozent"].mean()
# Out:
# Kanton
# Aargau                              37.398507
# Appenzell Ausserrhoden              35.780000
# Appenzell Innerrhoden               38.585714
# Basel-Landschaft                    33.510465
# Basel-Stadt                         41.200000
# Bern / Berne                        30.607186
# Fribourg / Freiburg                 35.988976
# Genève                              44.226087
# Glarus                              37.200000
# Graubünden / Grigioni / Grischun    40.825743
# Jura                                29.818868
# Luzern                              41.662963
# Neuchâtel                           37.100000
# Nidwalden                           46.627273
# Obwalden                            43.157143
# Schaffhausen                        41.492308
# Schwyz                              41.473333
# Solothurn                           33.740187
# St. Gallen                          38.082051
# Thurgau                             37.997531
# ...

# %%
data.groupby("Kanton")["Ja in Prozent"].agg([min, max])
# Out:
#                                    min   max
# Kanton
# Aargau                            11.9  53.5
# Appenzell Ausserrhoden            31.2  49.0
# Appenzell Innerrhoden             28.5  46.6
# Basel-Landschaft                  23.3  50.3
# Basel-Stadt                       31.8  49.4
# Bern / Berne                       4.5  51.4
# Fribourg / Freiburg               25.7  65.6
# Genève                            28.0  66.4
# Glarus                            35.8  38.3
# Graubünden / Grigioni / Grischun  24.3  75.0
# Jura                              16.6  45.9
# Luzern                            32.3  61.1
# Neuchâtel                         17.9  45.9
# Nidwalden                         41.4  56.9
# Obwalden                          39.2  50.1
# Schaffhausen                      32.9  49.3
# Schwyz                            23.2  60.3
# Solothurn                         23.2  57.1
# St. Gallen                        30.1  49.2
# Thurgau                           28.6  48.7
# ...

# %%
data.groupby(["Kantons-Nummer", "Kanton"])[["Stimmbeteiligung", "Ja in Prozent"]].agg([min, max])
# Out:
#                                                 Stimmbeteiligung        \
#                                                              min   max
# Kantons-Nummer Kanton
# 1              Zürich                                       21.3  59.9
# 2              Bern / Berne                                 30.9  69.7
# 3              Luzern                                       25.3  57.6
# 4              Uri                                          27.2  69.7
# 5              Schwyz                                       35.9  57.5
# 6              Obwalden                                     43.2  49.2
# 7              Nidwalden                                    42.4  50.7
# 8              Glarus                                       40.9  50.4
# 9              Zug                                          45.7  55.7
# 10             Fribourg / Freiburg                          27.9  65.9
# 11             Solothurn                                    31.2  62.7
# ...
