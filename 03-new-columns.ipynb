# %%
import pandas as pd

# %%
data = pd.read_csv("20220213_VolksabstimmungStempelabgaben.csv", delimiter = ";")

# %%
data.head()
# Out:
#    Kantons-Nummer  Kanton  Gemeinde-Nummer            Gemeinde  \
# 0               1  Zürich                1     Aeugst am Albis
# 1               1  Zürich                2  Affoltern am Albis
# 2               1  Zürich                3          Bonstetten
# 3               1  Zürich                4     Hausen am Albis
# 4               1  Zürich                5            Hedingen
#
#   Stimmberechtigte eingelegte Stimmzettel  Stimmbeteiligung leere Stimmzettel  \
# 0            1'415                    771              54.5                10
# 1            7'248                  3'284              45.3                59
# 2            3'665                  1'952              53.3                24
# 3            2'603                  1'378              52.9                33
# 4            2'504                  1'396              55.8                24
#
#    ungültige Stimmzettel gültige Stimmen Ja-Stimmen Nein-Stimmen  \
# ...

# %%
data["Ja in Dezimal"] = data["Ja in Prozent"] / 100
data["Ja in Dezimal"]
# Out:
# 0       0.396
# 1       0.357
# 2       0.362
# 3       0.395
# 4       0.371
#         ...
# 2151    0.440
# 2152    0.435
# 2153    0.446
# 2154    0.480
# 2155    0.367
# Name: Ja in Dezimal, Length: 2156, dtype: float64

# %% [markdown]
# Example of Data Wrangling with combination of the basics:

# %%
data["Stimmberechtigte"] = data["Stimmberechtigte"].str.replace('\'', '').astype(int)

# %%
data["Ja in Dezimal"] = data["Ja in Prozent"] / 100
voted_yes = data[data["Ja in Dezimal"] > .62]

# %%
voted_yes_sorted = voted_yes.sort_values("Stimmberechtigte", ascending=False)
voted_yes_sorted[["Gemeinde", "Kanton", "Stimmberechtigte", "Ja in Prozent"]]
# Out:
#                 Gemeinde                            Kanton  Stimmberechtigte  \
# 2061  Collonge-Bellerive                            Genève              4781
# 150              Uitikon                            Zürich              3247
# 2062             Cologny                            Genève              3013
# 2087         Vandoeuvres                            Genève              1547
# 1775          Crans (VD)                              Vaud              1305
# 1790        Signy-Avenex                              Vaud               327
# 748                Greng               Fribourg / Freiburg               126
# 1499            Bedretto                            Ticino               104
# 1166              Buseno  Graubünden / Grigioni / Grischun                77
# 1758           Rossenges                              Vaud                59
#
#       Ja in Prozent
# 2061           64.0
# 150            62.9
# 2062           66.4
# 2087           65.2
# ...
